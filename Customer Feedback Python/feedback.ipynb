# %%
# !pip install pandas textblob openpyxl
# Out:
# Requirement already satisfied: pandas in c:\users\local admin\appdata\local\programs\python\python313\lib\site-packages (2.3.1)
# Collecting textblob
#   Downloading textblob-0.20.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: openpyxl in c:\users\local admin\appdata\local\programs\python\python313\lib\site-packages (3.1.5)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\local admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\local admin\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\local admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\local admin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Collecting nltk>=3.9 (from textblob)
#   Downloading nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: et-xmlfile in c:\users\local admin\appdata\local\programs\python\python313\lib\site-packages (from openpyxl) (2.0.0)
# Collecting click (from nltk>=3.9->textblob)
#   Downloading click-8.4.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting joblib (from nltk>=3.9->textblob)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting regex>=2021.8.3 (from nltk>=3.9->textblob)
#   Downloading regex-2026.5.9-cp313-cp313-win_amd64.whl.metadata (41 kB)
# Collecting tqdm (from nltk>=3.9->textblob)
#   Downloading tqdm-4.67.3-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: six>=1.5 in c:\users\local admin\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\local admin\appdata\roaming\python\python313\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# Downloading textblob-0.20.0-py3-none-any.whl (624 kB)
#    ---------------------------------------- 0.0/625.0 kB ? eta -:--:--
#    ---------------- ----------------------- 262.1/625.0 kB ? eta -:--:--
#    ---------------------------------------- 625.0/625.0 kB 1.5 MB/s eta 0:00:00
# Downloading nltk-3.9.4-py3-none-any.whl (1.6 MB)
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.6 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.6 MB 2.0 MB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.6 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 1.9 MB/s eta 0:00:00
# Downloading regex-2026.5.9-cp313-cp313-win_amd64.whl (277 kB)
# Downloading click-8.4.0-py3-none-any.whl (116 kB)
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading tqdm-4.67.3-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm, regex, joblib, click, nltk, textblob
#
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ---------------------------------------- 0/6 [tqdm]
#    ------ --------------------------------- 1/6 [regex]
#    ------ --------------------------------- 1/6 [regex]
#    ------ --------------------------------- 1/6 [regex]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    ------------- -------------------------- 2/6 [joblib]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------- ------------------- 3/6 [click]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    -------------------------- ------------- 4/6 [nltk]
#    --------------------------------- ------ 5/6 [textblob]
#    --------------------------------- ------ 5/6 [textblob]
#    ---------------------------------------- 6/6 [textblob]
#
# Successfully installed click-8.4.0 joblib-1.5.3 nltk-3.9.4 regex-2026.5.9 textblob-0.20.0 tqdm-4.67.3
# [notice] A new release of pip is available: 25.1.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
from textblob import TextBlob

# %%
df = pd.read_excel("Insurance+Customer+Feedback.xlsx")

# %%
df.head(10)
# Out:
#      Customer Name                                           Feedback
# 0       John Smith  Excellent service, very satisfied with my policy.
# 1         Jane Doe  Had an issue with claim processing, but it was...
# 2    Emily Johnson  Very helpful customer service, answered all my...
# 3    Michael Brown  Premiums are a bit high, but overall a good ex...
# 4      Sarah Davis                 Fast and efficient claims process.
# 5     David Wilson  Policy options are confusing, need better expl...
# 6   Laura Martinez           Great value for money, highly recommend.
# 7  Robert Anderson    Long wait times on the phone, need improvement.
# 8   Jessica Thomas          Very satisfied with the coverage offered.
# 9       Daniel Lee  Easy to navigate website, found what I needed ...

# %% [markdown]
# ## SENTIMENT FUNCTION

# %%
def analyze_sentiment(text):
    
    analysis = TextBlob(str(text))
    polarity = analysis.sentiment.polarity

    if polarity > 0.8:
        return "Excellent"

    elif polarity < 0.6:
        return "Good"

    else:
        return "Needs Improvement"

# %%
df["Sentiment"] = df["Feedback"].apply(analyze_sentiment)

# %%
df.head
# Out:
# <bound method NDFrame.head of      Customer Name                                           Feedback  \
# 0       John Smith  Excellent service, very satisfied with my policy.
# 1         Jane Doe  Had an issue with claim processing, but it was...
# 2    Emily Johnson  Very helpful customer service, answered all my...
# 3    Michael Brown  Premiums are a bit high, but overall a good ex...
# 4      Sarah Davis                 Fast and efficient claims process.
# ..             ...                                                ...
# 92    Jennifer Cox  Had a minor issue with billing, but it was res...
# 93   Tyler Collins  Policy rates increased without notice, not happy.
# 94   Amanda Bailey  Great coverage options, very happy with my cho...
# 95  Raymond Howard  Website could be more intuitive, had trouble f...
# 96  Tiffany Carter  Professional and courteous staff, very satisfied.
#
#     Sentiment
# 0   Excellent
# 1        Good
# 2        Good
# 3        Good
# 4        Good
# ..        ...
# 92       Good
# 93       Good
# 94  Excellent
# 95       Good
# 96       Good
#
# [97 rows x 3 columns]>

# %%
df.to_excel("customer_feedback_analysis.xlsx", index=False)
